# %% [markdown]
# <a href="https://colab.research.google.com/github/Alyc3/Alyc3/blob/main/LypFD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ls
# Out:
# data/    options/       README.assets/  requirements/     trainer/  utils.py
# models/  preprocess.py  README.md       requirements.txt  train.py  validate.py

# %%
cd LipFD/
# Out:
# [Errno 2] No such file or directory: 'LipFD/'
# /content/LipFD

# %%
ls
# Out:
# data/    options/       README.assets/  requirements/     trainer/  utils.py
# models/  preprocess.py  README.md       requirements.txt  train.py  validate.py

# %%
# %%writefile requirements.txt
# ftfy==6.1.1
# librosa>=0.10.1
# matplotlib>=3.8.0
# numpy>=1.26
# opencv-contrib-python==4.8.1.78
# opencv-python==4.8.1.78
# scikit-learn>=1.3.1
# tqdm>=4.66.1
# Out:
# Overwriting requirements.txt

# %%
# !cat requirements.txt
# Out:
# ftfy==6.1.1
# librosa>=0.10.1
# matplotlib>=3.8.0
# numpy>=1.26
# opencv-contrib-python==4.8.1.78
# opencv-python==4.8.1.78
# scikit-learn>=1.3.1
# tqdm>=4.66.1

# %%
# !pip install --upgrade pip setuptools wheel
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached opencv_contrib_python-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# ...
#   Using cached opencv_python-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 MB 69.6 MB/s  0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 84.3 MB/s  0:00:00
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.13.0.92
#     Uninstalling opencv-python-4.13.0.92:
#       Successfully uninstalled opencv-python-4.13.0.92
#   Attempting uninstall: opencv-contrib-python
#     Found existing installation: opencv-contrib-python 4.13.0.92
#     Uninstalling opencv-contrib-python-4.13.0.92:
#       Successfully uninstalled opencv-contrib-python-4.13.0.92
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [opencv-contrib-python]
# ...

# %%
# Crear carpeta checkpoints si no existe
# !mkdir -p checkpoints

# %%
cd checkpoints/
# Out:
# /content/LipFD/checkpoints

# %%
# !cp /content/drive/MyDrive/ckpt.pth checkpoints/
# Out:
# cp: cannot stat '/content/drive/MyDrive/ckpt.pth': No such file or directory
